# %%
import datetime; datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2022-07-04 14:41:32'

# %% [markdown]
# # Vary the learner size while keeping the target fixed
#
# Changed the setting from the previous experiments.
#
# The output weights are U(-1,1) while the stepsize is greatly increased.
#
# The step-size is not swept over
#
# Replacement rate is now 20%
#
# Target size is now 100
#
# Replacemnent is every 20k steps here
#
# I fix the other preiods in order to account for the 20k replacement rate. Also training for longer

# %%
import mariadb
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import itertools
import matplotlib.ticker as ticker

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
#%matplotlib inline
import seaborn as sns
sns.set(
rc={
 'axes.axisbelow': False,
 'axes.edgecolor': 'black',
 'axes.facecolor': 'None',
 'axes.grid': False,
 "grid.color": "lightgrey",
 'axes.labelcolor': 'black',
 'axes.spines.right': False,
 'axes.spines.top': False,
 'figure.facecolor': 'white',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'text.color': 'black',
 'xtick.bottom': False,
 'xtick.color': 'black',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': 'black',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False,
    })
plt.rcParams["figure.figsize"] = (30,7)
sns.set_context("notebook", rc={"font.size":20,
                                "axes.titlesize":20,
                                "axes.labelsize":15})
# paper config below (uncomment)

plt.rcParams.update({
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'font.size': 15,
    'figure.autolayout': True,
    'figure.figsize': (7.2,4.45),
    'axes.titlesize' : 16,
    'axes.labelsize' : 17,
    'lines.linewidth' : 2,
    'lines.markersize' : 6,
    'legend.fontsize': '13',
    'mathtext.fontset': 'stix',
    'font.family': 'STIXGeneral',
    
    })

# some irrelavant config
#CB91_Blue = '#2CBDFE'
#CB91_Green = '#47DBCD'
#CB91_Pink = '#F3A0F2'
#CB91_Purple = '#9D2EC5'
#CB91_Violet = '#661D98'
#CB91_Amber = '#F5B14C'
#color_list = [CB91_Purple, CB91_Blue, CB91_Pink, CB91_Green,
#              CB91_Amber, CB91_Violet]
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=color_list)
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=sns.color_palette("bright"))
sns.color_palette("bright")
# Out:
# [(0.00784313725490196, 0.24313725490196078, 1.0),
#  (1.0, 0.48627450980392156, 0.0),
#  (0.10196078431372549, 0.788235294117647, 0.2196078431372549),
#  (0.9098039215686274, 0.0, 0.043137254901960784),
#  (0.5450980392156862, 0.16862745098039217, 0.8862745098039215),
#  (0.6235294117647059, 0.2823529411764706, 0.0),
#  (0.9450980392156862, 0.2980392156862745, 0.7568627450980392),
#  (0.6392156862745098, 0.6392156862745098, 0.6392156862745098),
#  (1.0, 0.7686274509803922, 0.0),
#  (0.0, 0.8431372549019608, 1.0)]

# %%
from cycler import cycler

fsize = 15
tsize = 18
tdir = 'in'
major = 5.0
minor = 3.0
lwidth = 0.7
lhandle = 2.0
plt.style.use('default')
plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = fsize
plt.rcParams['legend.fontsize'] = tsize
plt.rcParams['xtick.direction'] = tdir
plt.rcParams['ytick.direction'] = tdir
plt.rcParams['xtick.major.size'] = major
plt.rcParams['xtick.minor.size'] = minor
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['axes.linewidth'] = lwidth
plt.rcParams['legend.handlelength'] = lhandle

line_cycler   = (cycler(color=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]) +
                 cycler(linestyle=["-", "--", "-.", ":", "-", "--", "-."]))
marker_cycler = (cycler(color=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]) +
                 cycler(linestyle=["none", "none", "none", "none", "none", "none", "none"]) +
                 cycler(marker=["4", "2", "3", "1", "+", "x", "."]))
standard_cycler = cycler("color", ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
plt.rc("axes", prop_cycle=standard_cycler)

# %%
class DbAccessor:
    def __init__(self, db_name, cfg_primary_key="run_id", timestep_col_name="episode", local=False, gc=False, gc2=False):
        #params:
        #    cfg_primary_key: the key that is used to index the runs
        #    timestep_col_name: the column which contains the timestep values to be used in plots (or any other column to index with/use as x-axis)
        self.cfg_primary_key = cfg_primary_key
        self.timestep_col_name = timestep_col_name
        try:
            if local:
                    self.conn = mariadb.connect(user="haseebs",
                                                password="",
                                                host="localhost",
                                                port=3306,
                                                database=db_name)
            elif gc:
                self.conn = mariadb.connect(user='rlai',
                                            password=os.environ['gcpswd'],
                                            host='35.203.104.151',
                                            database=db_name)
            elif gc2:
                self.conn = mariadb.connect(user='narval',
                                            password=os.environ['narvalpswd'],
                                            host='34.152.53.247',
                                            database=db_name)
            else:
                # requires ssh tunnel to ccdb
                self.conn = mariadb.connect(user='hshah1',
                                            password=os.environ['cedarsqlpswd'],
                                            host='127.0.0.1',
                                            port=3307,
                                            database=db_name)
        except mariadb.Error as e:
            print(f"Error connecting to MariaDB Platform: {e}")
            sys.exit(1)

    def get_table_list(self):
        return pd.read_sql('show tables', self.conn)
    
    def get_table(self, table_name, cfg_filter=None, column_names="*", index=True):
        #params:
        #    cfg_filter: optional value of <cfg_primary_key> to filter the results with
        #    column_names: can be multiple
        #    index: whether the current table is indexed by <timestep_col_name>
        #returns:
        #    <timestep_col_name>'s values + <column_names>'s values
        
        #TODO careful with column names in future...
        if index:
            if column_names != "*":
                column_names += f',{self.timestep_col_name}'

            if cfg_filter:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name} WHERE {self.cfg_primary_key}={cfg_filter}', self.conn).set_index(self.timestep_col_name)
            else:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name}', self.conn).set_index(self.timestep_col_name)            
        else:
            if cfg_filter:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name} WHERE {self.cfg_primary_key}={cfg_filter}', self.conn)
            else:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name}', self.conn)

# %%
db1 = DbAccessor('hshah1_0388_mag_tester', cfg_primary_key="run", timestep_col_name="step", local=True, gc=False)
pd.read_sql(f'select * from runs', db1.conn)
# Out:
#                name  age_restriction  decorrelate_perc  l1_lambda  l2_lambda  \
# 0   0388_mag_tester                0               0.1        0.0        0.0
# 1   0388_mag_tester                0               0.1        0.0        0.0
# 2   0388_mag_tester                0               0.1        0.0        0.0
# 3   0388_mag_tester                0               0.1        0.0        0.0
# 4   0388_mag_tester                0               0.1        0.0        0.0
# 5   0388_mag_tester                0               0.1        0.0        0.0
# 6   0388_mag_tester                0               0.1        0.0        0.0
# 7   0388_mag_tester                0               0.1        0.0        0.0
# 8   0388_mag_tester                0               0.1        0.0        0.0
# 9   0388_mag_tester                0               0.1        0.0        0.0
# 10  0388_mag_tester                0               0.1        0.0        0.0
# 11  0388_mag_tester                0               0.1        0.0        0.0
# 12  0388_mag_tester                0               0.1        0.0        0.0
# 13  0388_mag_tester                0               0.1        0.0        0.0
# 14  0388_mag_tester                0               0.1        0.0        0.0
# 15  0388_mag_tester                0               0.1        0.0        0.0
# 16  0388_mag_tester                0               0.1        0.0        0.0
# 17  0388_mag_tester                0               0.1        0.0        0.0
# 18  0388_mag_tester                0               0.1        0.0        0.0
# 19  0388_mag_tester                0               0.1        0.0        0.0
# 20  0388_mag_tester                0               0.1        0.0        0.0
# 21  0388_mag_tester                0               0.1        0.0        0.0
# 22  0388_mag_tester                0               0.1        0.0        0.0
# 23  0388_mag_tester                0               0.1        0.0        0.0
# 24  0388_mag_tester                0               0.1        0.0        0.0
# 25  0388_mag_tester                0               0.1        0.0        0.0
# 26  0388_mag_tester                0               0.1        0.0        0.0
# 27  0388_mag_tester                0               0.1        0.0        0.0
# 28  0388_mag_tester                0               0.1        0.0        0.0
# 29  0388_mag_tester                0               0.1        0.0        0.0
#
#     min_estimation_period  n2_decorrelate  n_distractors  n_inputs  \
# 0                    5000               0              0         5
# 1                    5000               0              0         5
# 2                    5000               0              0         5
# 3                    5000               0              0         5
# 4                    5000               0              0         5
# 5                    5000               0              0         5
# 6                    5000               0              0         5
# 7                    5000               0              0         5
# 8                    5000               0              0         5
# 9                    5000               0              0         5
# 10                   5000               0              0         5
# 11                   5000               0              0         5
# 12                   5000               0              0         5
# 13                   5000               0              0         5
# 14                   5000               0              0         5
# 15                   5000               0              0         5
# 16                   5000               0              0         5
# 17                   5000               0              0         5
# 18                   5000               0              0         5
# 19                   5000               0              0         5
# 20                   5000               0              0         5
# 21                   5000               0              0         5
# 22                   5000               0              0         5
# 23                   5000               0              0         5
# 24                   5000               0              0         5
# 25                   5000               0              0         5
# 26                   5000               0              0         5
# 27                   5000               0              0         5
# 28                   5000               0              0         5
# 29                   5000               0              0         5
#
#     n_learner_features  ...  random_decorrelate  random_replacement  \
# 0                   25  ...                   0                   0
# 1                   25  ...                   0                   0
# 2                   25  ...                   0                   0
# 3                   25  ...                   0                   0
# 4                   25  ...                   0                   0
# 5                   25  ...                   0                   0
# 6                   25  ...                   0                   0
# 7                   25  ...                   0                   0
# 8                   25  ...                   0                   0
# 9                   25  ...                   0                   0
# 10                  25  ...                   0                   0
# 11                  25  ...                   0                   0
# 12                  25  ...                   0                   0
# 13                  25  ...                   0                   0
# 14                  25  ...                   0                   0
# 15                  25  ...                   0                   0
# 16                  25  ...                   0                   0
# 17                  25  ...                   0                   0
# 18                  25  ...                   0                   0
# 19                  25  ...                   0                   0
# 20                  25  ...                   0                   0
# 21                  25  ...                   0                   0
# 22                  25  ...                   0                   0
# 23                  25  ...                   0                   0
# 24                  25  ...                   0                   0
# 25                  25  ...                   0                   0
# 26                  25  ...                   0                   0
# 27                  25  ...                   0                   0
# 28                  25  ...                   0                   0
# 29                  25  ...                   0                   0
#
#     random_thresh_decorrelate  replace_every  replace_perc  seed  step_size  \
# 0                           0          20000           0.2     0       0.01
# 1                           0          20000           0.2     1       0.01
# 2                           0          20000           0.2     2       0.01
# 3                           0          20000           0.2     3       0.01
# 4                           0          20000           0.2     4       0.01
# 5                           0          20000           0.2     5       0.01
# 6                           0          20000           0.2     6       0.01
# 7                           0          20000           0.2     7       0.01
# 8                           0          20000           0.2     8       0.01
# 9                           0          20000           0.2     9       0.01
# 10                          0          20000           0.2    10       0.01
# 11                          0          20000           0.2    11       0.01
# 12                          0          20000           0.2    12       0.01
# 13                          0          20000           0.2    13       0.01
# 14                          0          20000           0.2    14       0.01
# 15                          0          20000           0.2    15       0.01
# 16                          0          20000           0.2    16       0.01
# 17                          0          20000           0.2    17       0.01
# 18                          0          20000           0.2    18       0.01
# 19                          0          20000           0.2    19       0.01
# 20                          0          20000           0.2    20       0.01
# 21                          0          20000           0.2    21       0.01
# 22                          0          20000           0.2    22       0.01
# 23                          0          20000           0.2    23       0.01
# 24                          0          20000           0.2    24       0.01
# 25                          0          20000           0.2    25       0.01
# 26                          0          20000           0.2    26       0.01
# 27                          0          20000           0.2    27       0.01
# 28                          0          20000           0.2    28       0.01
# 29                          0          20000           0.2    29       0.01
#
#        steps  sum_features  run
# 0   20000001             0    0
# 1   20000001             0    1
# 2   20000001             0    2
# 3   20000001             0    3
# 4   20000001             0    4
# 5   20000001             0    5
# 6   20000001             0    6
# 7   20000001             0    7
# 8   20000001             0    8
# 9   20000001             0    9
# 10  20000001             0   10
# 11  20000001             0   11
# 12  20000001             0   12
# 13  20000001             0   13
# 14  20000001             0   14
# 15  20000001             0   15
# 16  20000001             0   16
# 17  20000001             0   17
# 18  20000001             0   18
# 19  20000001             0   19
# 20  20000001             0   20
# 21  20000001             0   21
# 22  20000001             0   22
# 23  20000001             0   23
# 24  20000001             0   24
# 25  20000001             0   25
# 26  20000001             0   26
# 27  20000001             0   27
# 28  20000001             0   28
# 29  20000001             0   29
#
# [30 rows x 22 columns]

# %%
db2 = DbAccessor('hshah1_0389_decor_tester', cfg_primary_key="run", timestep_col_name="step", local=True, gc=False)
pd.read_sql(f'select * from runs', db2.conn)
# Out:
#                  name  age_restriction  decorrelate_perc  l1_lambda  \
# 0   0389_decor_tester                0               0.1        0.0
# 1   0389_decor_tester                0               0.1        0.0
# 2   0389_decor_tester                0               0.1        0.0
# 3   0389_decor_tester                0               0.1        0.0
# 4   0389_decor_tester                0               0.1        0.0
# 5   0389_decor_tester                0               0.1        0.0
# 6   0389_decor_tester                0               0.1        0.0
# 7   0389_decor_tester                0               0.1        0.0
# 8   0389_decor_tester                0               0.1        0.0
# 9   0389_decor_tester                0               0.1        0.0
# 10  0389_decor_tester                0               0.1        0.0
# 11  0389_decor_tester                0               0.1        0.0
# 12  0389_decor_tester                0               0.1        0.0
# 13  0389_decor_tester                0               0.1        0.0
# 14  0389_decor_tester                0               0.1        0.0
# 15  0389_decor_tester                0               0.1        0.0
# 16  0389_decor_tester                0               0.1        0.0
# 17  0389_decor_tester                0               0.1        0.0
# 18  0389_decor_tester                0               0.1        0.0
# 19  0389_decor_tester                0               0.1        0.0
# 20  0389_decor_tester                0               0.1        0.0
# 21  0389_decor_tester                0               0.1        0.0
# 22  0389_decor_tester                0               0.1        0.0
# 23  0389_decor_tester                0               0.1        0.0
# 24  0389_decor_tester                0               0.1        0.0
# 25  0389_decor_tester                0               0.1        0.0
# 26  0389_decor_tester                0               0.1        0.0
# 27  0389_decor_tester                0               0.1        0.0
# 28  0389_decor_tester                0               0.1        0.0
# 29  0389_decor_tester                0               0.1        0.0
# 30  0389_decor_tester                0               0.1        0.0
# 31  0389_decor_tester                0               0.1        0.0
# 32  0389_decor_tester                0               0.1        0.0
# 33  0389_decor_tester                0               0.1        0.0
# 34  0389_decor_tester                0               0.1        0.0
# 35  0389_decor_tester                0               0.1        0.0
# 36  0389_decor_tester                0               0.1        0.0
# 37  0389_decor_tester                0               0.1        0.0
# 38  0389_decor_tester                0               0.1        0.0
# 39  0389_decor_tester                0               0.1        0.0
# 40  0389_decor_tester                0               0.1        0.0
# 41  0389_decor_tester                0               0.1        0.0
# 42  0389_decor_tester                0               0.1        0.0
# 43  0389_decor_tester                0               0.1        0.0
# 44  0389_decor_tester                0               0.1        0.0
# 45  0389_decor_tester                0               0.1        0.0
# 46  0389_decor_tester                0               0.1        0.0
# 47  0389_decor_tester                0               0.1        0.0
# 48  0389_decor_tester                0               0.1        0.0
# 49  0389_decor_tester                0               0.1        0.0
# 50  0389_decor_tester                0               0.1        0.0
# 51  0389_decor_tester                0               0.1        0.0
# 52  0389_decor_tester                0               0.1        0.0
# 53  0389_decor_tester                0               0.1        0.0
# 54  0389_decor_tester                0               0.1        0.0
# 55  0389_decor_tester                0               0.1        0.0
# 56  0389_decor_tester                0               0.1        0.0
# 57  0389_decor_tester                0               0.1        0.0
# 58  0389_decor_tester                0               0.1        0.0
# 59  0389_decor_tester                0               0.1        0.0
#
#     l2_lambda  min_estimation_period  n2_decorrelate  n_distractors  n_inputs  \
# 0         0.0                   5000               0              0         5
# 1         0.0                   5000               1              0         5
# 2         0.0                   5000               0              0         5
# 3         0.0                   5000               1              0         5
# 4         0.0                   5000               0              0         5
# 5         0.0                   5000               1              0         5
# 6         0.0                   5000               0              0         5
# 7         0.0                   5000               1              0         5
# 8         0.0                   5000               0              0         5
# 9         0.0                   5000               1              0         5
# 10        0.0                   5000               0              0         5
# 11        0.0                   5000               1              0         5
# 12        0.0                   5000               0              0         5
# 13        0.0                   5000               1              0         5
# 14        0.0                   5000               0              0         5
# 15        0.0                   5000               1              0         5
# 16        0.0                   5000               0              0         5
# 17        0.0                   5000               1              0         5
# 18        0.0                   5000               0              0         5
# 19        0.0                   5000               1              0         5
# 20        0.0                   5000               0              0         5
# 21        0.0                   5000               1              0         5
# 22        0.0                   5000               0              0         5
# 23        0.0                   5000               1              0         5
# 24        0.0                   5000               0              0         5
# 25        0.0                   5000               1              0         5
# 26        0.0                   5000               0              0         5
# 27        0.0                   5000               1              0         5
# 28        0.0                   5000               0              0         5
# 29        0.0                   5000               1              0         5
# 30        0.0                   5000               0              0         5
# 31        0.0                   5000               1              0         5
# 32        0.0                   5000               0              0         5
# 33        0.0                   5000               1              0         5
# 34        0.0                   5000               0              0         5
# 35        0.0                   5000               1              0         5
# 36        0.0                   5000               0              0         5
# 37        0.0                   5000               1              0         5
# 38        0.0                   5000               0              0         5
# 39        0.0                   5000               1              0         5
# 40        0.0                   5000               0              0         5
# 41        0.0                   5000               1              0         5
# 42        0.0                   5000               0              0         5
# 43        0.0                   5000               1              0         5
# 44        0.0                   5000               0              0         5
# 45        0.0                   5000               1              0         5
# 46        0.0                   5000               0              0         5
# 47        0.0                   5000               1              0         5
# 48        0.0                   5000               0              0         5
# 49        0.0                   5000               1              0         5
# 50        0.0                   5000               0              0         5
# 51        0.0                   5000               1              0         5
# 52        0.0                   5000               0              0         5
# 53        0.0                   5000               1              0         5
# 54        0.0                   5000               0              0         5
# 55        0.0                   5000               1              0         5
# 56        0.0                   5000               0              0         5
# 57        0.0                   5000               1              0         5
# 58        0.0                   5000               0              0         5
# 59        0.0                   5000               1              0         5
#
#     n_learner_features  ...  random_decorrelate  random_replacement  \
# 0                   25  ...                   1                   0
# 1                   25  ...                   1                   0
# 2                   25  ...                   1                   0
# 3                   25  ...                   1                   0
# 4                   25  ...                   1                   0
# 5                   25  ...                   1                   0
# 6                   25  ...                   1                   0
# 7                   25  ...                   1                   0
# 8                   25  ...                   1                   0
# 9                   25  ...                   1                   0
# 10                  25  ...                   1                   0
# 11                  25  ...                   1                   0
# 12                  25  ...                   1                   0
# 13                  25  ...                   1                   0
# 14                  25  ...                   1                   0
# 15                  25  ...                   1                   0
# 16                  25  ...                   1                   0
# 17                  25  ...                   1                   0
# 18                  25  ...                   1                   0
# 19                  25  ...                   1                   0
# 20                  25  ...                   1                   0
# 21                  25  ...                   1                   0
# 22                  25  ...                   1                   0
# 23                  25  ...                   1                   0
# 24                  25  ...                   1                   0
# 25                  25  ...                   1                   0
# 26                  25  ...                   1                   0
# 27                  25  ...                   1                   0
# 28                  25  ...                   1                   0
# 29                  25  ...                   1                   0
# 30                  25  ...                   1                   0
# 31                  25  ...                   1                   0
# 32                  25  ...                   1                   0
# 33                  25  ...                   1                   0
# 34                  25  ...                   1                   0
# 35                  25  ...                   1                   0
# 36                  25  ...                   1                   0
# 37                  25  ...                   1                   0
# 38                  25  ...                   1                   0
# 39                  25  ...                   1                   0
# 40                  25  ...                   1                   0
# 41                  25  ...                   1                   0
# 42                  25  ...                   1                   0
# 43                  25  ...                   1                   0
# 44                  25  ...                   1                   0
# 45                  25  ...                   1                   0
# 46                  25  ...                   1                   0
# 47                  25  ...                   1                   0
# 48                  25  ...                   1                   0
# 49                  25  ...                   1                   0
# 50                  25  ...                   1                   0
# 51                  25  ...                   1                   0
# 52                  25  ...                   1                   0
# 53                  25  ...                   1                   0
# 54                  25  ...                   1                   0
# 55                  25  ...                   1                   0
# 56                  25  ...                   1                   0
# 57                  25  ...                   1                   0
# 58                  25  ...                   1                   0
# 59                  25  ...                   1                   0
#
#     random_thresh_decorrelate  replace_every  replace_perc  seed  step_size  \
# 0                           0          20000           0.2     0       0.01
# 1                           0          20000           0.2     0       0.01
# 2                           0          20000           0.2     1       0.01
# 3                           0          20000           0.2     1       0.01
# 4                           0          20000           0.2     2       0.01
# 5                           0          20000           0.2     2       0.01
# 6                           0          20000           0.2     3       0.01
# 7                           0          20000           0.2     3       0.01
# 8                           0          20000           0.2     4       0.01
# 9                           0          20000           0.2     4       0.01
# 10                          0          20000           0.2     5       0.01
# 11                          0          20000           0.2     5       0.01
# 12                          0          20000           0.2     6       0.01
# 13                          0          20000           0.2     6       0.01
# 14                          0          20000           0.2     7       0.01
# 15                          0          20000           0.2     7       0.01
# 16                          0          20000           0.2     8       0.01
# 17                          0          20000           0.2     8       0.01
# 18                          0          20000           0.2     9       0.01
# 19                          0          20000           0.2     9       0.01
# 20                          0          20000           0.2    10       0.01
# 21                          0          20000           0.2    10       0.01
# 22                          0          20000           0.2    11       0.01
# 23                          0          20000           0.2    11       0.01
# 24                          0          20000           0.2    12       0.01
# 25                          0          20000           0.2    12       0.01
# 26                          0          20000           0.2    13       0.01
# 27                          0          20000           0.2    13       0.01
# 28                          0          20000           0.2    14       0.01
# 29                          0          20000           0.2    14       0.01
# 30                          0          20000           0.2    15       0.01
# 31                          0          20000           0.2    15       0.01
# 32                          0          20000           0.2    16       0.01
# 33                          0          20000           0.2    16       0.01
# 34                          0          20000           0.2    17       0.01
# 35                          0          20000           0.2    17       0.01
# 36                          0          20000           0.2    18       0.01
# 37                          0          20000           0.2    18       0.01
# 38                          0          20000           0.2    19       0.01
# 39                          0          20000           0.2    19       0.01
# 40                          0          20000           0.2    20       0.01
# 41                          0          20000           0.2    20       0.01
# 42                          0          20000           0.2    21       0.01
# 43                          0          20000           0.2    21       0.01
# 44                          0          20000           0.2    22       0.01
# 45                          0          20000           0.2    22       0.01
# 46                          0          20000           0.2    23       0.01
# 47                          0          20000           0.2    23       0.01
# 48                          0          20000           0.2    24       0.01
# 49                          0          20000           0.2    24       0.01
# 50                          0          20000           0.2    25       0.01
# 51                          0          20000           0.2    25       0.01
# 52                          0          20000           0.2    26       0.01
# 53                          0          20000           0.2    26       0.01
# 54                          0          20000           0.2    27       0.01
# 55                          0          20000           0.2    27       0.01
# 56                          0          20000           0.2    28       0.01
# 57                          0          20000           0.2    28       0.01
# 58                          0          20000           0.2    29       0.01
# 59                          0          20000           0.2    29       0.01
#
#        steps  sum_features  run
# 0   20000001             0    0
# 1   20000001             0    1
# 2   20000001             0    2
# 3   20000001             0    3
# 4   20000001             0    4
# 5   20000001             0    5
# 6   20000001             0    6
# 7   20000001             0    7
# 8   20000001             0    8
# 9   20000001             0    9
# 10  20000001             0   10
# 11  20000001             0   11
# 12  20000001             0   12
# 13  20000001             0   13
# 14  20000001             0   14
# 15  20000001             0   15
# 16  20000001             0   16
# 17  20000001             0   17
# 18  20000001             0   18
# 19  20000001             0   19
# 20  20000001             0   20
# 21  20000001             0   21
# 22  20000001             0   22
# 23  20000001             0   23
# 24  20000001             0   24
# 25  20000001             0   25
# 26  20000001             0   26
# 27  20000001             0   27
# 28  20000001             0   28
# 29  20000001             0   29
# 30  20000001             0   30
# 31  20000001             0   31
# 32  20000001             0   32
# 33  20000001             0   33
# 34  20000001             0   34
# 35  20000001             0   35
# 36  20000001             0   36
# 37  20000001             0   37
# 38  20000001             0   38
# 39  20000001             0   39
# 40  20000001             0   40
# 41  20000001             0   41
# 42  20000001             0   42
# 43  20000001             0   43
# 44  20000001             0   44
# 45  20000001             0   45
# 46  20000001             0   46
# 47  20000001             0   47
# 48  20000001             0   48
# 49  20000001             0   49
# 50  20000001             0   50
# 51  20000001             0   51
# 52  20000001             0   52
# 53  20000001             0   53
# 54  20000001             0   54
# 55  20000001             0   55
# 56  20000001             0   56
# 57  20000001             0   57
# 58  20000001             0   58
# 59  20000001             0   59
#
# [60 rows x 22 columns]

# %%
db4 = DbAccessor('hshah1_0387_l2_baseline_fixedss', cfg_primary_key="run", timestep_col_name="step", local=True, gc=False)
pd.read_sql(f'select * from runs', db4.conn)
# Out:
#                         name  age_restriction  decorrelate_perc  l1_lambda  \
# 0   0387_l2_baseline_fixedss                0               0.1        0.0
# 1   0387_l2_baseline_fixedss                0               0.1        0.0
# 2   0387_l2_baseline_fixedss                0               0.1        0.0
# 3   0387_l2_baseline_fixedss                0               0.1        0.0
# 4   0387_l2_baseline_fixedss                0               0.1        0.0
# 5   0387_l2_baseline_fixedss                0               0.1        0.0
# 6   0387_l2_baseline_fixedss                0               0.1        0.0
# 7   0387_l2_baseline_fixedss                0               0.1        0.0
# 8   0387_l2_baseline_fixedss                0               0.1        0.0
# 9   0387_l2_baseline_fixedss                0               0.1        0.0
# 10  0387_l2_baseline_fixedss                0               0.1        0.0
# 11  0387_l2_baseline_fixedss                0               0.1        0.0
# 12  0387_l2_baseline_fixedss                0               0.1        0.0
# 13  0387_l2_baseline_fixedss                0               0.1        0.0
# 14  0387_l2_baseline_fixedss                0               0.1        0.0
# 15  0387_l2_baseline_fixedss                0               0.1        0.0
# 16  0387_l2_baseline_fixedss                0               0.1        0.0
# 17  0387_l2_baseline_fixedss                0               0.1        0.0
# 18  0387_l2_baseline_fixedss                0               0.1        0.0
# 19  0387_l2_baseline_fixedss                0               0.1        0.0
# 20  0387_l2_baseline_fixedss                0               0.1        0.0
# 21  0387_l2_baseline_fixedss                0               0.1        0.0
# 22  0387_l2_baseline_fixedss                0               0.1        0.0
# 23  0387_l2_baseline_fixedss                0               0.1        0.0
# 24  0387_l2_baseline_fixedss                0               0.1        0.0
# 25  0387_l2_baseline_fixedss                0               0.1        0.0
# 26  0387_l2_baseline_fixedss                0               0.1        0.0
# 27  0387_l2_baseline_fixedss                0               0.1        0.0
# 28  0387_l2_baseline_fixedss                0               0.1        0.0
# 29  0387_l2_baseline_fixedss                0               0.1        0.0
#
#     l2_lambda  min_estimation_period  n2_decorrelate  n_distractors  n_inputs  \
# 0         0.1                   5000               0              0         5
# 1         0.1                   5000               0              0         5
# 2         0.1                   5000               0              0         5
# 3         0.1                   5000               0              0         5
# 4         0.1                   5000               0              0         5
# 5         0.1                   5000               0              0         5
# 6         0.1                   5000               0              0         5
# 7         0.1                   5000               0              0         5
# 8         0.1                   5000               0              0         5
# 9         0.1                   5000               0              0         5
# 10        0.1                   5000               0              0         5
# 11        0.1                   5000               0              0         5
# 12        0.1                   5000               0              0         5
# 13        0.1                   5000               0              0         5
# 14        0.1                   5000               0              0         5
# 15        0.1                   5000               0              0         5
# 16        0.1                   5000               0              0         5
# 17        0.1                   5000               0              0         5
# 18        0.1                   5000               0              0         5
# 19        0.1                   5000               0              0         5
# 20        0.1                   5000               0              0         5
# 21        0.1                   5000               0              0         5
# 22        0.1                   5000               0              0         5
# 23        0.1                   5000               0              0         5
# 24        0.1                   5000               0              0         5
# 25        0.1                   5000               0              0         5
# 26        0.1                   5000               0              0         5
# 27        0.1                   5000               0              0         5
# 28        0.1                   5000               0              0         5
# 29        0.1                   5000               0              0         5
#
#     n_learner_features  ...  random_decorrelate  random_replacement  \
# 0                   25  ...                   0                   0
# 1                   25  ...                   0                   0
# 2                   25  ...                   0                   0
# 3                   25  ...                   0                   0
# 4                   25  ...                   0                   0
# 5                   25  ...                   0                   0
# 6                   25  ...                   0                   0
# 7                   25  ...                   0                   0
# 8                   25  ...                   0                   0
# 9                   25  ...                   0                   0
# 10                  25  ...                   0                   0
# 11                  25  ...                   0                   0
# 12                  25  ...                   0                   0
# 13                  25  ...                   0                   0
# 14                  25  ...                   0                   0
# 15                  25  ...                   0                   0
# 16                  25  ...                   0                   0
# 17                  25  ...                   0                   0
# 18                  25  ...                   0                   0
# 19                  25  ...                   0                   0
# 20                  25  ...                   0                   0
# 21                  25  ...                   0                   0
# 22                  25  ...                   0                   0
# 23                  25  ...                   0                   0
# 24                  25  ...                   0                   0
# 25                  25  ...                   0                   0
# 26                  25  ...                   0                   0
# 27                  25  ...                   0                   0
# 28                  25  ...                   0                   0
# 29                  25  ...                   0                   0
#
#     random_thresh_decorrelate  replace_every  replace_perc  seed  step_size  \
# 0                           0          20000           0.2     0       0.01
# 1                           0          20000           0.2     1       0.01
# 2                           0          20000           0.2     2       0.01
# 3                           0          20000           0.2     3       0.01
# 4                           0          20000           0.2     4       0.01
# 5                           0          20000           0.2     5       0.01
# 6                           0          20000           0.2     6       0.01
# 7                           0          20000           0.2     7       0.01
# 8                           0          20000           0.2     8       0.01
# 9                           0          20000           0.2     9       0.01
# 10                          0          20000           0.2    10       0.01
# 11                          0          20000           0.2    11       0.01
# 12                          0          20000           0.2    12       0.01
# 13                          0          20000           0.2    13       0.01
# 14                          0          20000           0.2    14       0.01
# 15                          0          20000           0.2    15       0.01
# 16                          0          20000           0.2    16       0.01
# 17                          0          20000           0.2    17       0.01
# 18                          0          20000           0.2    18       0.01
# 19                          0          20000           0.2    19       0.01
# 20                          0          20000           0.2    20       0.01
# 21                          0          20000           0.2    21       0.01
# 22                          0          20000           0.2    22       0.01
# 23                          0          20000           0.2    23       0.01
# 24                          0          20000           0.2    24       0.01
# 25                          0          20000           0.2    25       0.01
# 26                          0          20000           0.2    26       0.01
# 27                          0          20000           0.2    27       0.01
# 28                          0          20000           0.2    28       0.01
# 29                          0          20000           0.2    29       0.01
#
#        steps  sum_features  run
# 0   20000001             0    0
# 1   20000001             0    1
# 2   20000001             0    2
# 3   20000001             0    3
# 4   20000001             0    4
# 5   20000001             0    5
# 6   20000001             0    6
# 7   20000001             0    7
# 8   20000001             0    8
# 9   20000001             0    9
# 10  20000001             0   10
# 11  20000001             0   11
# 12  20000001             0   12
# 13  20000001             0   13
# 14  20000001             0   14
# 15  20000001             0   15
# 16  20000001             0   16
# 17  20000001             0   17
# 18  20000001             0   18
# 19  20000001             0   19
# 20  20000001             0   20
# 21  20000001             0   21
# 22  20000001             0   22
# 23  20000001             0   23
# 24  20000001             0   24
# 25  20000001             0   25
# 26  20000001             0   26
# 27  20000001             0   27
# 28  20000001             0   28
# 29  20000001             0   29
#
# [30 rows x 22 columns]

# %%
db3 = DbAccessor('hshah1_0393_l2_baseline_best', cfg_primary_key="run", timestep_col_name="step", local=True, gc=False)
pd.read_sql(f'select * from runs', db3.conn)
# Out:
#                      name  age_restriction  decorrelate_perc  l1_lambda  \
# 0   0393_l2_baseline_best                0               0.1        0.0
# 1   0393_l2_baseline_best                0               0.1        0.0
# 2   0393_l2_baseline_best                0               0.1        0.0
# 3   0393_l2_baseline_best                0               0.1        0.0
# 4   0393_l2_baseline_best                0               0.1        0.0
# 5   0393_l2_baseline_best                0               0.1        0.0
# 6   0393_l2_baseline_best                0               0.1        0.0
# 7   0393_l2_baseline_best                0               0.1        0.0
# 8   0393_l2_baseline_best                0               0.1        0.0
# 9   0393_l2_baseline_best                0               0.1        0.0
# 10  0393_l2_baseline_best                0               0.1        0.0
# 11  0393_l2_baseline_best                0               0.1        0.0
# 12  0393_l2_baseline_best                0               0.1        0.0
# 13  0393_l2_baseline_best                0               0.1        0.0
# 14  0393_l2_baseline_best                0               0.1        0.0
# 15  0393_l2_baseline_best                0               0.1        0.0
# 16  0393_l2_baseline_best                0               0.1        0.0
# 17  0393_l2_baseline_best                0               0.1        0.0
# 18  0393_l2_baseline_best                0               0.1        0.0
# 19  0393_l2_baseline_best                0               0.1        0.0
# 20  0393_l2_baseline_best                0               0.1        0.0
# 21  0393_l2_baseline_best                0               0.1        0.0
# 22  0393_l2_baseline_best                0               0.1        0.0
# 23  0393_l2_baseline_best                0               0.1        0.0
# 24  0393_l2_baseline_best                0               0.1        0.0
# 25  0393_l2_baseline_best                0               0.1        0.0
# 26  0393_l2_baseline_best                0               0.1        0.0
# 27  0393_l2_baseline_best                0               0.1        0.0
# 28  0393_l2_baseline_best                0               0.1        0.0
# 29  0393_l2_baseline_best                0               0.1        0.0
#
#     l2_lambda  min_estimation_period  n2_decorrelate  n_distractors  n_inputs  \
# 0        0.01                   5000               0              0         5
# 1        0.01                   5000               0              0         5
# 2        0.01                   5000               0              0         5
# 3        0.01                   5000               0              0         5
# 4        0.01                   5000               0              0         5
# 5        0.01                   5000               0              0         5
# 6        0.01                   5000               0              0         5
# 7        0.01                   5000               0              0         5
# 8        0.01                   5000               0              0         5
# 9        0.01                   5000               0              0         5
# 10       0.01                   5000               0              0         5
# 11       0.01                   5000               0              0         5
# 12       0.01                   5000               0              0         5
# 13       0.01                   5000               0              0         5
# 14       0.01                   5000               0              0         5
# 15       0.01                   5000               0              0         5
# 16       0.01                   5000               0              0         5
# 17       0.01                   5000               0              0         5
# 18       0.01                   5000               0              0         5
# 19       0.01                   5000               0              0         5
# 20       0.01                   5000               0              0         5
# 21       0.01                   5000               0              0         5
# 22       0.01                   5000               0              0         5
# 23       0.01                   5000               0              0         5
# 24       0.01                   5000               0              0         5
# 25       0.01                   5000               0              0         5
# 26       0.01                   5000               0              0         5
# 27       0.01                   5000               0              0         5
# 28       0.01                   5000               0              0         5
# 29       0.01                   5000               0              0         5
#
#     n_learner_features  ...  random_decorrelate  random_replacement  \
# 0                   25  ...                   0                   0
# 1                   25  ...                   0                   0
# 2                   25  ...                   0                   0
# 3                   25  ...                   0                   0
# 4                   25  ...                   0                   0
# 5                   25  ...                   0                   0
# 6                   25  ...                   0                   0
# 7                   25  ...                   0                   0
# 8                   25  ...                   0                   0
# 9                   25  ...                   0                   0
# 10                  25  ...                   0                   0
# 11                  25  ...                   0                   0
# 12                  25  ...                   0                   0
# 13                  25  ...                   0                   0
# 14                  25  ...                   0                   0
# 15                  25  ...                   0                   0
# 16                  25  ...                   0                   0
# 17                  25  ...                   0                   0
# 18                  25  ...                   0                   0
# 19                  25  ...                   0                   0
# 20                  25  ...                   0                   0
# 21                  25  ...                   0                   0
# 22                  25  ...                   0                   0
# 23                  25  ...                   0                   0
# 24                  25  ...                   0                   0
# 25                  25  ...                   0                   0
# 26                  25  ...                   0                   0
# 27                  25  ...                   0                   0
# 28                  25  ...                   0                   0
# 29                  25  ...                   0                   0
#
#     random_thresh_decorrelate  replace_every  replace_perc  seed  step_size  \
# 0                           0          20000           0.2     0       0.01
# 1                           0          20000           0.2     1       0.01
# 2                           0          20000           0.2     2       0.01
# 3                           0          20000           0.2     3       0.01
# 4                           0          20000           0.2     4       0.01
# 5                           0          20000           0.2     5       0.01
# 6                           0          20000           0.2     6       0.01
# 7                           0          20000           0.2     7       0.01
# 8                           0          20000           0.2     8       0.01
# 9                           0          20000           0.2     9       0.01
# 10                          0          20000           0.2    10       0.01
# 11                          0          20000           0.2    11       0.01
# 12                          0          20000           0.2    12       0.01
# 13                          0          20000           0.2    13       0.01
# 14                          0          20000           0.2    14       0.01
# 15                          0          20000           0.2    15       0.01
# 16                          0          20000           0.2    16       0.01
# 17                          0          20000           0.2    17       0.01
# 18                          0          20000           0.2    18       0.01
# 19                          0          20000           0.2    19       0.01
# 20                          0          20000           0.2    20       0.01
# 21                          0          20000           0.2    21       0.01
# 22                          0          20000           0.2    22       0.01
# 23                          0          20000           0.2    23       0.01
# 24                          0          20000           0.2    24       0.01
# 25                          0          20000           0.2    25       0.01
# 26                          0          20000           0.2    26       0.01
# 27                          0          20000           0.2    27       0.01
# 28                          0          20000           0.2    28       0.01
# 29                          0          20000           0.2    29       0.01
#
#        steps  sum_features  run
# 0   20000001             0    0
# 1   20000001             0    1
# 2   20000001             0    2
# 3   20000001             0    3
# 4   20000001             0    4
# 5   20000001             0    5
# 6   20000001             0    6
# 7   20000001             0    7
# 8   20000001             0    8
# 9   20000001             0    9
# 10  20000001             0   10
# 11  20000001             0   11
# 12  20000001             0   12
# 13  20000001             0   13
# 14  20000001             0   14
# 15  20000001             0   15
# 16  20000001             0   16
# 17  20000001             0   17
# 18  20000001             0   18
# 19  20000001             0   19
# 20  20000001             0   20
# 21  20000001             0   21
# 22  20000001             0   22
# 23  20000001             0   23
# 24  20000001             0   24
# 25  20000001             0   25
# 26  20000001             0   26
# 27  20000001             0   27
# 28  20000001             0   28
# 29  20000001             0   29
#
# [30 rows x 22 columns]

# %%
from scipy.ndimage.filters import uniform_filter1d
def moving_avg(x, n):
    return uniform_filter1d(x, size=n)
    #cumsum = np.cumsum(np.insert(x, 0, 0)) 
    #return (cumsum[n:] - cumsum[:-n]) / float(n)

# %%
def plt_individual(comment, NSTEPS, min_steps, db, color, label=None, condition=[], table='test_metrics', plot_conf=True, linestyle='-', pkey_col = "run_id", nocomment=False, nolabel=False, linewidth=None, col=None, alpha=1, smoothing_n=1):
    #NSTEPS : number of entries
    if label==None:
        label=comment
    if col is None:
        if table == 'training_metrics':
            col = 'running_acc'
        elif table == 'error_table' or table == "test_accuracy":
            col = 'error'
        else:
            col = 'acc'
    suitable_runs = pd.read_sql(f'select {pkey_col} from {table} group by {pkey_col} having max({db.timestep_col_name}) > {min_steps}', db.conn).values
    #suitable_runs = [s for s in suitable_runs if len(db.get_table(table, s[0], col).values.reshape(-1)) >= NSTEPS]
        
    runs = []
    invalid_count = 0
    if nocomment:
        # too lazy
        if condition == []:
            r = pd.read_sql(f'select {pkey_col} from runs ', db.conn).values
        elif len(condition) == 1:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} ', db.conn).values
        elif len(condition) == 2:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} ', db.conn).values
        elif len(condition) == 3:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]}', db.conn).values
        elif len(condition) == 4:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]}', db.conn).values
        elif len(condition) == 5:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]} and {condition[4][0]} = {condition[4][1]}', db.conn).values
        if len(r) !=0:
            runs = r

    runs = [r for r in runs if len(db.get_table(table, r[0], col).values.reshape(-1)) >= NSTEPS]
    if len(runs) == 0:
        print("\t 0 runs for ", condition)
        return False
    else:
        print(f'\t Found {len(runs)} valid runs for {condition}')

    acc_all = np.zeros((len(runs), NSTEPS-5))
    for i,run in enumerate(runs):
        acc_all[i,:] =  moving_avg(db.get_table(table, run[0], col).values[5:NSTEPS].reshape(-1), smoothing_n)
    acc_mean = np.mean(acc_all, axis=0)
    
    x_axis = db.get_table(table, run[0], col).index[5:NSTEPS].to_numpy()
    if linewidth is None:
        linewidth = plt.rcParams["lines.linewidth"]
        if linestyle == ":":
            linewidth = plt.rcParams["lines.linewidth"]/2
    
    for i, run in enumerate(runs):
        if nolabel:
            plt.plot(x_axis, acc_all[i,:], color=color, linestyle=linestyle, linewidth=linewidth, alpha=alpha)
        else:
            plt.plot(x_axis, acc_all[i,:], label=f"run {i}", color=color, linestyle=linestyle, linewidth=linewidth, alpha=alpha)
    return True

# %%
def plt_individual_corr(comment, NSTEPS, min_steps, db, colors, label=None, condition=[], table='test_metrics', plot_conf=True, linestyle='-', pkey_col = "run_id", nocomment=False, nolabel=False, linewidth=None, col=None, alpha=1, features=50):
    #NSTEPS : number of entries
    if label==None:
        label=comment
    if col is None:
        if table == 'training_metrics':
            col = 'running_acc'
        elif table == 'error_table' or table == "test_accuracy":
            col = 'error'
        else:
            col = 'acc'
    suitable_runs = pd.read_sql(f'select {pkey_col} from {table} group by {pkey_col} having max({db.timestep_col_name}) > {min_steps}', db.conn).values
    #suitable_runs = [s for s in suitable_runs if len(db.get_table(table, s[0], col).values.reshape(-1)) >= NSTEPS]
        
    runs = []
    invalid_count = 0
    if nocomment:
        # too lazy
        if condition == []:
            r = pd.read_sql(f'select {pkey_col} from runs ', db.conn).values
        elif len(condition) == 1:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} ', db.conn).values
        elif len(condition) == 2:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} ', db.conn).values
        elif len(condition) == 3:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]}', db.conn).values
        elif len(condition) == 4:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]}', db.conn).values
        elif len(condition) == 5:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]} and {condition[4][0]} = {condition[4][1]}', db.conn).values
        if len(r) !=0:
            runs = r

    runs = [r for r in runs if len(db.get_table(table, r[0], col).values.reshape(-1)) >= NSTEPS]
    if len(runs) == 0:
        print("\t 0 runs for ", condition)
        return False
    else:
        print(f'\t Found {len(runs)} valid runs for {condition}')

    acc_all = np.zeros((len(runs), NSTEPS))
    for i,run in enumerate(runs):
        acc_all[i,:] =  db.get_table(table, run[0], col).values[:NSTEPS].reshape(-1)
    acc_mean = np.mean(acc_all, axis=0)
    
    x_axis = db.get_table(table, run[0], col).index[:NSTEPS].to_numpy()
    if linewidth is None:
        linewidth = plt.rcParams["lines.linewidth"]
        if linestyle == ":":
            linewidth = plt.rcParams["lines.linewidth"]/2
    
    for i, run in enumerate(runs):
        plt.plot(x_axis, 100*acc_all[i,:]/features, label=f"run {i}", color=colors[i], linestyle=linestyle, linewidth=linewidth, alpha=alpha)
    return True

# %%
def plt_with_err_mature(comment, NSTEPS, min_steps, db, color, label=None, condition=[], table='test_metrics', plot_conf=True, linestyle='-', pkey_col = "run_id", nocomment=False, nolabel=False, linewidth=None, col=None, features=50):
    #NSTEPS : number of entries
    if label==None:
        label=comment
        
    col = "n_mature"
    suitable_runs = pd.read_sql(f'select {pkey_col} from {table} group by {pkey_col} having max({db.timestep_col_name}) > {min_steps}', db.conn).values
    #suitable_runs = [s for s in suitable_runs if len(db.get_table(table, s[0], col).values.reshape(-1)) >= NSTEPS]
        
    runs = []
    invalid_count = 0
    if nocomment:
        # too lazy
        if condition == []:
            r = pd.read_sql(f'select {pkey_col} from runs ', db.conn).values
        elif len(condition) == 1:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} ', db.conn).values
        elif len(condition) == 2:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} ', db.conn).values
        elif len(condition) == 3:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]}', db.conn).values
        elif len(condition) == 4:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]}', db.conn).values
        elif len(condition) == 5:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]} and {condition[4][0]} = {condition[4][1]}', db.conn).values
        if len(r) !=0:
            runs = r

    runs = [r for r in runs if len(db.get_table(table, r[0], col).values.reshape(-1)) >= NSTEPS]
    if len(runs) == 0:
        print("\t 0 runs for ", condition)
        return False
    else:
        print(f'\t Found {len(runs)} valid runs for {condition}')

        
    acc_sums = 0
    total_runs = 0
    for run in runs:
        acc_sums += db.get_table(table, run[0], col).values[:NSTEPS].reshape(-1)
        total_runs += 1
    mean_acc = acc_sums / total_runs



    acc_all = np.zeros((len(runs), NSTEPS))
    for i,run in enumerate(runs):
        acc_all[i,:] =  100*db.get_table(table, run[0], col).values[:NSTEPS].reshape(-1) / features
    acc_mean = np.mean(acc_all, axis=0)
    acc_std = np.std(acc_all, axis=0)/np.sqrt(total_runs)
    x_axis = db.get_table(table, run[0], col).index[:NSTEPS].to_numpy()
    #plt.errorbar(x_axis, acc_mean, yerr=acc_std*1.96, label=f"{label} | runs: {total_runs} | invalid: {invalid_count}", color=color)
    if linewidth is None:
        linewidth = plt.rcParams["lines.linewidth"]
            
    if nolabel:
        plt.plot(x_axis, acc_mean, color=color, linestyle=linestyle, linewidth=linewidth)
    else:
        plt.plot(x_axis, acc_mean, label=f"{label} | valid runs: {total_runs}", color=color, linestyle=linestyle, linewidth=linewidth)
        #plt.plot(x_axis, acc_mean, label=f"{label}", color=color, linestyle=linestyle, linewidth=linewidth)
    if plot_conf:
        plt.fill_between(x_axis, acc_mean-acc_std, acc_mean+acc_std, alpha=0.16, color=color, edgecolor=None)
    return True

# %%
def plt_with_err_corr(comment, NSTEPS, min_steps, db, color, label=None, condition=[], table='test_metrics', plot_conf=True, linestyle='-', pkey_col = "run_id", nocomment=False, nolabel=False, linewidth=None, col=None, features=50, smoothing_n=1):
    #NSTEPS : number of entries
    if label==None:
        label=comment
        
    col1 = "n_correlated"
    col2 = "n_mature"
    suitable_runs = pd.read_sql(f'select {pkey_col} from {table} group by {pkey_col} having max({db.timestep_col_name}) > {min_steps}', db.conn).values
    #suitable_runs = [s for s in suitable_runs if len(db.get_table(table, s[0], col).values.reshape(-1)) >= NSTEPS]
        
    runs = []
    invalid_count = 0
    if nocomment:
        # too lazy
        if condition == []:
            r = pd.read_sql(f'select {pkey_col} from runs ', db.conn).values
        elif len(condition) == 1:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} ', db.conn).values
        elif len(condition) == 2:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} ', db.conn).values
        elif len(condition) == 3:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]}', db.conn).values
        elif len(condition) == 4:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]}', db.conn).values
        elif len(condition) == 5:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]} and {condition[4][0]} = {condition[4][1]}', db.conn).values
        if len(r) !=0:
            runs = r

    runs = [r for r in runs if len(db.get_table(table, r[0], col1).values.reshape(-1)) >= NSTEPS]
    if len(runs) == 0:
        print("\t 0 runs for ", condition)
        return False
    else:
        print(f'\t Found {len(runs)} valid runs for {condition}')

        
    total_runs = len(runs)
    
    acc_all = np.zeros((len(runs), NSTEPS))
    for i,run in enumerate(runs):
        acc_all[i,:] =  moving_avg(100 * (db.get_table(table, run[0], col1).values[:NSTEPS].reshape(-1) / (db.get_table(table, run[0], col2).values[:NSTEPS].reshape(-1)+0.001)), smoothing_n)

    acc_mean = np.mean(acc_all, axis=0)
    acc_std = np.std(acc_all, axis=0)/np.sqrt(total_runs)
    x_axis = db.get_table(table, run[0], col1).index[:NSTEPS].to_numpy()
    #plt.errorbar(x_axis, acc_mean, yerr=acc_std*1.96, label=f"{label} | runs: {total_runs} | invalid: {invalid_count}", color=color)
    if linewidth is None:
        linewidth = plt.rcParams["lines.linewidth"]
            
    if nolabel:
        plt.plot(x_axis, acc_mean, color=color, linestyle=linestyle, linewidth=linewidth)
    else:
        plt.plot(x_axis, acc_mean, label=f"{label} | valid runs: {total_runs}", color=color, linestyle=linestyle, linewidth=linewidth)
        #plt.plot(x_axis, acc_mean, label=f"{label}", color=color, linestyle=linestyle, linewidth=linewidth)
    if plot_conf:
        plt.fill_between(x_axis, acc_mean-acc_std, acc_mean+acc_std, alpha=0.16, color=color, edgecolor=None)
    return True

# %%
def plt_with_err(comment, NSTEPS, min_steps, db, color, label=None, condition=[], table='test_metrics', plot_conf=True, linestyle='-', pkey_col = "run_id", nocomment=False, nolabel=False, linewidth=None, col=None, smoothing_n=1, begin_at=0):
    #NSTEPS : number of entries
    if label==None:
        label=comment
    if col is None:
        if table == 'training_metrics':
            col = 'running_acc'
        elif table == 'error_table' or table == "test_accuracy":
            col = 'error'
        else:
            col = 'acc'
    suitable_runs = pd.read_sql(f'select {pkey_col} from {table} group by {pkey_col} having max({db.timestep_col_name}) > {min_steps}', db.conn).values
    #suitable_runs = [s for s in suitable_runs if len(db.get_table(table, s[0], col).values.reshape(-1)) >= NSTEPS]
        
    runs = []
    invalid_count = 0
    if nocomment:
        # too lazy
        if condition == []:
            r = pd.read_sql(f'select {pkey_col} from runs ', db.conn).values
        elif len(condition) == 1:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} ', db.conn).values
        elif len(condition) == 2:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} ', db.conn).values
        elif len(condition) == 3:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]}', db.conn).values
        elif len(condition) == 4:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]}', db.conn).values
        elif len(condition) == 5:
            r = pd.read_sql(f'select {pkey_col} from runs where {condition[0][0]} = {condition[0][1]} and {condition[1][0]} = {condition[1][1]} and {condition[2][0]} = {condition[2][1]} and {condition[3][0]} = {condition[3][1]} and {condition[4][0]} = {condition[4][1]}', db.conn).values
        if len(r) !=0:
            runs = r

    runs = [r for r in runs if len(db.get_table(table, r[0], col).values.reshape(-1)) >= NSTEPS]
    if len(runs) == 0:
        print("\t 0 runs for ", condition)
        return False
    else:
        print(f'\t Found {len(runs)} valid runs for {condition}')

        
    acc_sums = 0
    total_runs = 0
    for run in runs:
        acc_sums += db.get_table(table, run[0], col).values[begin_at:NSTEPS].reshape(-1)
        total_runs += 1
    mean_acc = acc_sums / total_runs



    acc_all = np.zeros((len(runs), NSTEPS-begin_at))
    for i,run in enumerate(runs):
        acc_all[i,:] =  moving_avg(db.get_table(table, run[0], col).values[begin_at:NSTEPS].reshape(-1),smoothing_n)
    acc_mean = np.mean(acc_all, axis=0)
    acc_std = np.std(acc_all, axis=0)/np.sqrt(total_runs)
    x_axis = db.get_table(table, run[0], col).index[begin_at:NSTEPS].to_numpy()
    #plt.errorbar(x_axis, acc_mean, yerr=acc_std*1.96, label=f"{label} | runs: {total_runs} | invalid: {invalid_count}", color=color)
    if linewidth is None:
        linewidth = plt.rcParams["lines.linewidth"]
        if linestyle == ":":
            linewidth = plt.rcParams["lines.linewidth"]/2
    if nolabel:
        plt.plot(x_axis, acc_mean, color=color, linestyle=linestyle, linewidth=linewidth)
    else:
        plt.plot(x_axis, acc_mean, label=f"{label} | valid runs: {total_runs}", color=color, linestyle=linestyle, linewidth=linewidth)
        #plt.plot(x_axis, acc_mean, label=f"{label}", color=color, linestyle=linestyle, linewidth=linewidth)
    if plot_conf:
        plt.fill_between(x_axis, acc_mean-acc_std, acc_mean+acc_std, alpha=0.16, color=color, edgecolor=None)
    return True

# %%
n_learner_features=25
plt_name = f'confidence level of order one-sigma effect, learner 25, target 100'
fig, axs = plt.subplots(dpi=200)
plt.title(plt_name)
#plt.title(plt_name)
plt.xlabel('Timesteps')
plt.ylabel('MSE', rotation="horizontal", ha="right", ma="center", va="center")
axs.xaxis.set_tick_params(which='major', bottom=True)
axs.xaxis.set_tick_params(which='minor', bottom=True)
axs.minorticks_on()

colors = plt.cycler(color=sns.color_palette("Set1", n_colors=10)).by_key()['color']
#colors = plt.cycler(color=sns.color_palette("tab10", n_colors=4)).by_key()['color']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]


color_idx = 0
conditions = [["n_learner_features", n_learner_features]]

plt_with_err("", 4*1000, 0, db1, colors[color_idx], f'Magnitude Tester', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db1, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

conditions = [["n_learner_features", n_learner_features],
              ["n2_decorrelate", 1]]
color_idx+=1
plt_with_err("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + O(N2) decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

conditions = [["n_learner_features", n_learner_features],
              ["n2_decorrelate", 0],
              ["random_decorrelate", 1]]
color_idx+=1

plt_with_err("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + Random decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)
conditions = []
color_idx+=1

plt_with_err("", 4*1000, 0, db3, colors[color_idx], f'Magnitude Tester + L2 Regularizer', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

#plt_with_err("", 4*1000, 0, db4, colors[color_idx], f'Magnitude Tester + L2 Regularizer', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

legend = plt.legend(prop={'size': 9}, bbox_to_anchor=(1.04,1), loc="upper left")
#plt.axhline(y=0.00, color='black', linestyle=':', linewidth=2, alpha=0.3)

frame = legend.get_frame()
#frame.set_edgecolor('black')
frame.set_linewidth(0.5)
frame.set_boxstyle('Square')
plt.yscale('linear')
fig.axes[0].set_ylim(top=1.8)
plt.savefig('figures/plt_decor_err_25_100_0041.svg', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# 	 Found 30 valid runs for [['n_learner_features', 25]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 1]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 0], ['random_decorrelate', 1]]
# 	 Found 30 valid runs for []

# %%
n_learner_features=25
plt_name = f'confidence level of order one-sigma effect, learner 25, target 100'
fig, axs = plt.subplots(dpi=200)
plt.title(plt_name)
#plt.title(plt_name)
plt.xlabel('Timesteps')
plt.ylabel('MSE', rotation="horizontal", ha="right", ma="center", va="center")
axs.xaxis.set_tick_params(which='major', bottom=True)
axs.xaxis.set_tick_params(which='minor', bottom=True)
axs.minorticks_on()

colors = plt.cycler(color=sns.color_palette("Set1", n_colors=10)).by_key()['color']
#colors = plt.cycler(color=sns.color_palette("tab10", n_colors=4)).by_key()['color']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]


color_idx = 0
conditions = [["n_learner_features", n_learner_features]]

plt_with_err("", 4*1000, 0, db1, colors[color_idx], f'Magnitude Tester', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db1, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

conditions = [["n_learner_features", n_learner_features],
              ["n2_decorrelate", 1]]
color_idx+=1
plt_with_err("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + O(N2) decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

conditions = [["n_learner_features", n_learner_features],
              ["n2_decorrelate", 0],
              ["random_decorrelate", 1]]
color_idx+=1

plt_with_err("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + Random decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)
conditions = []
color_idx+=1

plt_with_err("", 4*1000, 0, db3, colors[color_idx], f'Magnitude Tester + L2 Regularizer', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

plt_with_err("", 4*1000, 0, db4, colors[color_idx], f'Magnitude Tester + L2 Regularizer', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", smoothing_n=10)
#plt_individual("", 5*2000, 0, db2, colors[color_idx], None, conditions, "error_table", plot_conf=False, pkey_col = "run", nocomment=True, nolabel=True, linewidth=0.4, linestyle="-", alpha=0.1, smoothing_n=30)

legend = plt.legend(prop={'size': 9}, bbox_to_anchor=(1.04,1), loc="upper left")
#plt.axhline(y=0.00, color='black', linestyle=':', linewidth=2, alpha=0.3)

frame = legend.get_frame()
#frame.set_edgecolor('black')
frame.set_linewidth(0.5)
frame.set_boxstyle('Square')
plt.yscale('linear')
fig.axes[0].set_ylim(top=2.7)
plt.savefig('figures/plt_err_all_new_l2.svg', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# 	 Found 30 valid runs for [['n_learner_features', 25]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 1]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 0], ['random_decorrelate', 1]]
# 	 Found 30 valid runs for []
# 	 Found 30 valid runs for []

# %%
n_learner_features=25
plt_name = f'confidence level of order one-sigma effect, learner 25, target 100'
fig, axs = plt.subplots(dpi=200)
plt.title(plt_name)
#plt.title(plt_name)
plt.xlabel('Timesteps')
plt.ylabel('Percentage of mature features \nwith g.t. 0.85 correlation', rotation="horizontal", ha="right", ma="center", va="center")
axs.xaxis.set_tick_params(which='major', bottom=True)
axs.xaxis.set_tick_params(which='minor', bottom=True)
axs.minorticks_on()

colors = plt.cycler(color=sns.color_palette("Set1", n_colors=10)).by_key()['color']
#colors = plt.cycler(color=sns.color_palette("tab10", n_colors=4)).by_key()['color']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]

color_idx = 0
conditions = [["n_learner_features", n_learner_features]]

plt_with_err_corr("", 4*1000, 0, db1, colors[color_idx], f'Magnitude Tester', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features, smoothing_n=10)
conditions = [["n_learner_features", n_learner_features],
      ["n2_decorrelate", 1]]
color_idx+=1
plt_with_err_corr("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + O(N2) decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features,smoothing_n=10)

conditions = [["n_learner_features", n_learner_features],
      ["n2_decorrelate", 0],
      ["random_decorrelate", 1]]
color_idx+=1
plt_with_err_corr("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + Random decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features,smoothing_n=10)
conditions = []
color_idx+=1
plt_with_err_corr("", 4*1000, 0, db3, colors[color_idx], f'Magnitude Tester + L2 Regularizer', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features,smoothing_n=10)
#plt_with_err_corr("", 4*1000, 0, db4, colors[color_idx], f'Magnitude Tester + L2 Regularizer', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features,smoothing_n=10)


legend = plt.legend(prop={'size': 9}, bbox_to_anchor=(1.04,1), loc="upper left")
#plt.axhline(y=0.00, color='black', linestyle=':', linewidth=2, alpha=0.3)

frame = legend.get_frame()
#frame.set_edgecolor('black')
frame.set_linewidth(0.5)
frame.set_boxstyle('Square')
plt.yscale('linear')
#fig.axes[0].set_ylim(top=90)
plt.savefig('figures/plt_decor_corr_25_100_0041.svg', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# 	 Found 30 valid runs for [['n_learner_features', 25]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 1]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 0], ['random_decorrelate', 1]]
# 	 Found 30 valid runs for []

# %%
n_learner_features=25
plt_name = f'confidence level of order one-sigma effect, learner 25, target 100'
fig, axs = plt.subplots(dpi=200)
plt.title(plt_name)
#plt.title(plt_name)
plt.xlabel('Timesteps')
plt.ylabel('Percentage of mature features \nwith g.t. 0.85 correlation', rotation="horizontal", ha="right", ma="center", va="center")
axs.xaxis.set_tick_params(which='major', bottom=True)
axs.xaxis.set_tick_params(which='minor', bottom=True)
axs.minorticks_on()

colors = plt.cycler(color=sns.color_palette("Set1", n_colors=10)).by_key()['color']
#colors = plt.cycler(color=sns.color_palette("tab10", n_colors=4)).by_key()['color']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]

color_idx = 0
conditions = [["n_learner_features", n_learner_features]]

plt_with_err_corr("", 4*1000, 0, db1, colors[color_idx], f'Magnitude Tester', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features, smoothing_n=10)
conditions = [["n_learner_features", n_learner_features],
      ["n2_decorrelate", 1]]
color_idx+=1
plt_with_err_corr("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + O(N2) decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features,smoothing_n=10)

conditions = [["n_learner_features", n_learner_features],
      ["n2_decorrelate", 0],
      ["random_decorrelate", 1]]
color_idx+=1
plt_with_err_corr("", 4*1000, 0, db2, colors[color_idx], f'Magnitude Tester + Random decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features,smoothing_n=10)
conditions = []
color_idx+=1
plt_with_err_corr("", 4*1000, 0, db3, colors[color_idx], f'Magnitude Tester + L2 Regularizer', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features,smoothing_n=10)


legend = plt.legend(prop={'size': 9}, bbox_to_anchor=(1.04,1), loc="upper left")
#plt.axhline(y=0.00, color='black', linestyle=':', linewidth=2, alpha=0.3)

frame = legend.get_frame()
#frame.set_edgecolor('black')
frame.set_linewidth(0.5)
frame.set_boxstyle('Square')
plt.yscale('linear')
#fig.axes[0].set_ylim(top=90)
plt.savefig('figures/plt_corr_all_transp.svg', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# 	 Found 30 valid runs for [['n_learner_features', 25]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 1]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 0], ['random_decorrelate', 1]]
# 	 Found 30 valid runs for []

# %%
n_learner_features=25
plt_name = f'confidence level of order one-sigma effect, learner 25, target 100'
fig, axs = plt.subplots(dpi=200)
plt.title(plt_name)
#plt.title(plt_name)
plt.xlabel('Timesteps')
plt.ylabel('Percentage of mature features \nwith g.t. 0.85 correlation', rotation="horizontal", ha="right", ma="center", va="center")
axs.xaxis.set_tick_params(which='major', bottom=True)
axs.xaxis.set_tick_params(which='minor', bottom=True)
axs.minorticks_on()

colors = plt.cycler(color=sns.color_palette("Set1", n_colors=10)).by_key()['color']
#colors = plt.cycler(color=sns.color_palette("tab10", n_colors=4)).by_key()['color']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]

color_idx = 0
conditions = [["n_learner_features", n_learner_features]]

plt_with_err_corr("", 1000, 0, db1, colors[color_idx], f'Magnitude Tester', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features)
conditions = [["n_learner_features", n_learner_features],
      ["n2_decorrelate", 1]]
color_idx+=1
plt_with_err_corr("", 1000, 0, db2, colors[color_idx], f'Magnitude Tester + O(N2) decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features)

conditions = [["n_learner_features", n_learner_features],
      ["n2_decorrelate", 0],
      ["random_decorrelate", 1]]
color_idx+=1
plt_with_err_corr("", 1000, 0, db2, colors[color_idx], f'Magnitude Tester + Random decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features)
conditions = []
color_idx+=1
plt_with_err_corr("", 1000, 0, db3, colors[color_idx], f'Magnitude Tester + Random decorrelator', conditions, "error_table", plot_conf=True, pkey_col = "run", nocomment=True, linewidth=0.7, linestyle="-", features=n_learner_features)


legend = plt.legend(prop={'size': 9}, bbox_to_anchor=(1.04,1), loc="upper left")
#plt.axhline(y=0.00, color='black', linestyle=':', linewidth=2, alpha=0.3)

frame = legend.get_frame()
#frame.set_edgecolor('black')
frame.set_linewidth(0.5)
frame.set_boxstyle('Square')
plt.yscale('linear')
#fig.axes[0].set_ylim(top=90)
#plt.savefig('figures/plt_mnist.svg', bbox_inches='tight')
plt.show()
# Out:
# 	 Found 30 valid runs for [['n_learner_features', 25]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 1]]
# 	 Found 30 valid runs for [['n_learner_features', 25], ['n2_decorrelate', 0], ['random_decorrelate', 1]]
# 	 Found 30 valid runs for []
